# %% [markdown]
# <a href="https://colab.research.google.com/github/2049066gael-guevara/Gael-Guevara-Puente-2049066/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt # generar gráficos
import numpy as np # generar arreglos
import pandas as pd # cargar conjuntos de datos externos
import sklearn.linear_model # contiene diferentes modelos de ML
from sklearn.preprocessing import MinMaxScaler #Normalizar los valores

rs = pd.read_csv("robot_sensors.csv", thousands = ',')
rs.head(4) # Segundo Paso. Mostrar las primeras (0,1,2,3) filas del dataset

rs2=rs.dropna()
(rs2[rs2["Velocidad (cm/s)"]<0]).head(5) #buscar valores negativos de la velocidad (no hay)
rs3=rs2.drop(rs2[rs2["Velocidad (cm/s)"]<0].index)


rsn=(rs-rs.min())/(rs.max()-rs.min())



rsn.plot(kind='line', x="Tiempo (s)", y="Distancia (cm)")
rsn.plot(kind='line', x="Tiempo (s)", y="Velocidad (cm/s)")
rsn.plot(kind='line', x="Tiempo (s)", y="Temperatura (°C)")

plt.show()
rsn
# Out:
#      Tiempo (s)  Distancia (cm)  Velocidad (cm/s)  Temperatura (°C)
# 0      0.000000        0.371735          0.182609          0.262269
# 1      0.001001        0.950755          0.540740          0.247509
# 2      0.002002        0.730954          0.873049          0.908233
# 3      0.003003        0.596960          0.731791          0.250082
# 4      0.004004        0.152134          0.806411          0.272535
# ..          ...             ...               ...               ...
# 995    0.995996        0.087379          0.656234          0.867184
# 996    0.996997        0.917189          0.957037          0.157607
# 997    0.997998        0.132839          0.065991          0.310456
# 998    0.998999        0.950275          0.054042          0.290671
# 999    1.000000        0.443554          0.280034          0.873316
#
# [1000 rows x 4 columns]
